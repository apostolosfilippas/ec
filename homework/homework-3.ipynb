# %% [markdown]
# ---
#
# ### 🎓 **Professor**: Apostolos Filippas
#
# ### 📘 **Class**: AI and Data-Driven Marketplaces
#
# ### 📋 **Topic**: Data Visualization Practice
#
# 🚫 **Note**: You are not allowed to share the contents of this notebook with anyone outside this class without written permission by the professor.
#
# ---
#
# # Homework 3

# %% [markdown]
# > **Before you begin, get the latest course files:**
# >
# > - **If you cloned the repository:** Open the `ma` folder in VS Code, choose **Terminal → New Terminal**, type `git pull`, and press Enter. You can also run this command in your computer's terminal from inside the `ma` folder.
# > - **If you need to download the homework:** Open [Homework 3 on GitHub](https://github.com/apostolosfilippas/ma/blob/main/homework/homework-3.ipynb), click **Download raw file** (the download arrow), and open the downloaded notebook in VS Code.

# %% [markdown]
# In the `homes.csv` dataset, do the following.
#
# **Hint:** You'll need to import pandas, matplotlib, and possibly seaborn. The dataset is in the course repository's `data` folder. From this notebook in the `homework` folder, use `../data/homes.csv`; if your notebook runs from the repository root, use `data/homes.csv`.
#
# ```python
# import pandas as pd
# import matplotlib.pyplot as plt
# df_homes = pd.read_csv("../data/homes.csv")
# ```

# %% [markdown]
# ## 1. Compute the averages
#
# For `CHARLOTTESVILLE`, `CROZET`, `EARLYSVILLE`, `KESWICK`, `SCOTTSVILLE`, and `NORTH GARDEN`, compute the average value per square foot for homes built after 1990.

# %%
# Write your code here.

# %% [markdown]
# ## 2. Create a plot
#
# - Put each city on the x-axis.
# - Represent each mean you computed in step 1 with one point on the y-axis.

# %%
# Write your code here.
